# %%
from pymatreader import read_mat
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = list(read_mat('features_matrices/DEAP/Afeat_matrix_all_DEAP.mat').values())[3]
colnames = list(read_mat('features_matrices/DEAP/colnames_DEAP.mat').values())[3]

# %%
read_mat('features_matrices/DREAMER/Afeat_matrix_all_DEAP.mat')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 read_mat('features_matrices/DREAMER/Afeat_matrix_all_DEAP.mat')
#
# File ~/anaconda3/envs/eegain/lib/python3.12/site-packages/pymatreader/pymatreader.py:81, in read_mat(filename, variable_names, ignore_fields, uint16_codec)
#      52 """This function reads .mat files of version <7.3 or 7.3 and returns the
#      53 contained data structure as a dictionary of nested substructure similar
#      54 to scipy.io.loadmat style.
#    (...)
#      77     variable data as values.
#      78 """
#      80 if not os.path.exists(filename):
# ---> 81     raise IOError('The file %s does not exist.' % (filename,))
#      83 if ignore_fields is None:
#      84     ignore_fields = []
#
# OSError: The file features_matrices/DREAMER/Afeat_matrix_all_DEAP.mat does not exist.

# %%
df = pd.DataFrame(data=data, columns=colnames,)
df[df['task'] == 1]
# Out:
#       subj  task       d_1        th_1       a_1         b_1   d_rel_1  \
# 0      1.0   1.0  0.006423    8.695362  0.006423    8.695362  0.000155
# 40     2.0   1.0  0.688928  104.764501  0.688928  104.764501  0.002687
# 80     3.0   1.0  0.049894   11.317377  0.049894   11.317377  0.000800
# 120    4.0   1.0  0.034134  207.673731  0.034134  207.673731  0.000066
# 160    5.0   1.0  0.076354   40.697034  0.076354   40.697034  0.000474
# 200    6.0   1.0  0.031848   20.435769  0.031848   20.435769  0.000363
# 240    7.0   1.0  0.096766   28.311071  0.096766   28.311071  0.000709
# 280    8.0   1.0  0.039970   16.336597  0.039970   16.336597  0.000549
# 320    9.0   1.0  0.112198   41.162313  0.112198   41.162313  0.001085
# 360   10.0   1.0  0.122326   70.176330  0.122326   70.176330  0.000558
# 400   11.0   1.0  0.284866   70.427111  0.284866   70.427111  0.001094
# 440   12.0   1.0  0.171848   42.281186  0.171848   42.281186  0.000943
# ...
