# %%
from pymatreader import read_mat
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = read_mat('features_matrices/DREAMER/feat_array_all_DREAMER.mat')['feat_array_all_DREAMER']
colnames = read_mat('features_matrices/DREAMER/colnames_DREAMER.mat')['colnames']

# %%
df = pd.DataFrame(data, columns=colnames,)
df[df['task'] == 1]
# Out:
#      subj  task         d_1       th_1         a_1        b_1   d_rel_1  \
# 0     1.0   1.0   96.122090  25.764123   96.122090  25.764123  0.004519
# 36    2.0   1.0   98.240461  29.565228   98.240461  29.565228  0.004616
# 72    3.0   1.0  123.272099  30.080163  123.272099  30.080163  0.005808
# 108   4.0   1.0   87.322633  50.673315   87.322633  50.673315  0.004157
# 144   5.0   1.0  240.321082  74.700707  240.321082  74.700707  0.011182
# 180   6.0   1.0  155.456864  61.247351  155.456864  61.247351  0.007380
# 216   7.0   1.0  106.334843  43.745014  106.334843  43.745014  0.005142
# 252   8.0   1.0  234.471633  46.405251  234.471633  46.405251  0.010945
# 288   9.0   1.0  150.514222  41.719281  150.514222  41.719281  0.007122
# 324  10.0   1.0   96.784040  36.842513   96.784040  36.842513  0.004583
# 360  11.0   1.0  111.195333  23.894039  111.195333  23.894039  0.005247
# 396  12.0   1.0  114.708636  28.831523  114.708636  28.831523  0.005572
# ...
